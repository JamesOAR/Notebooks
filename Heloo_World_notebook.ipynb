# %% [markdown]
# INitial Test of pandas dataframe

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    # time    strain  stress kPa  stress_exp
# 0  1120.0  0.000000    0.147971   -0.078071
# 1  1120.1  0.000178    0.164174   -0.077713
# 2  1120.2  0.000357    0.180399   -0.076761
# 3  1120.3  0.000535    0.196644   -0.101613
# 4  1120.4  0.000714    0.212911   -0.076826
